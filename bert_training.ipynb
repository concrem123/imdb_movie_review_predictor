# %% [markdown]
# <a href="https://colab.research.google.com/github/concrem123/imdb_movie_review_predictor/blob/main/bert_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/concrem123/imdb_movie_review_predictor.git
# Out:
# Cloning into 'imdb_movie_review_predictor'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 64 (delta 3), reused 4 (delta 2), pack-reused 56 (from 1)
# Receiving objects: 100% (64/64), 50.27 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !cp /content/data.zip imdb_movie_review_predictor/

# %%
# !unzip /content/imdb_movie_review_predictor/data.zip
# Out:
# Archive:  /content/imdb_movie_review_predictor/data.zip
#    creating: data/
#   inflating: __MACOSX/._data
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/processed/
#   inflating: __MACOSX/data/._processed
#    creating: data/processed/imdb_tokenized_withtext/
#   inflating: __MACOSX/data/processed/._imdb_tokenized_withtext
#   inflating: data/processed/.DS_Store
#   inflating: __MACOSX/data/processed/._.DS_Store
#    creating: data/processed/imdb_tokenized/
#   inflating: __MACOSX/data/processed/._imdb_tokenized
#   inflating: data/processed/imdb_tokenized_withtext/dataset_dict.json
#   inflating: __MACOSX/data/processed/imdb_tokenized_withtext/._dataset_dict.json
#    creating: data/processed/imdb_tokenized_withtext/test/
#   inflating: __MACOSX/data/processed/imdb_tokenized_withtext/._test
#    creating: data/processed/imdb_tokenized_withtext/train/
#   inflating: __MACOSX/data/processed/imdb_tokenized_withtext/._train
# ...

# %%
# %cd /content/imdb_movie_review_predictor
# !pip install -r requirements.txt
# Out:
# /content/imdb_movie_review_predictor
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 136.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/imdb_movie_review_predictor
# !python src/preprocess.py
# Out:
# /content/imdb_movie_review_predictor
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 339kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 8.62MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 18.7MB/s]
# config.json: 100% 483/483 [00:00<00:00, 4.38MB/s]
# README.md: 7.81kB [00:00, 25.7MB/s]
# plain_text/train-00000-of-00001.parquet: 100% 21.0M/21.0M [00:00<00:00, 64.9MB/s]
# plain_text/test-00000-of-00001.parquet: 100% 20.5M/20.5M [00:00<00:00, 45.1MB/s]
# plain_text/unsupervised-00000-of-00001.p(…): 100% 42.0M/42.0M [00:00<00:00, 64.4MB/s]
# Generating train split: 100% 25000/25000 [00:00<00:00, 121818.51 examples/s]
# Generating test split: 100% 25000/25000 [00:00<00:00, 172016.99 examples/s]
# Generating unsupervised split: 100% 50000/50000 [00:00<00:00, 162594.12 examples/s]
# Map: 100% 17500/17500 [01:19<00:00, 219.83 examples/s]
# Map: 100% 2500/2500 [00:10<00:00, 227.32 examples/s]
# Map: 100% 5000/5000 [00:21<00:00, 231.89 examples/s]
# ...

# %%
# %cd /content/imdb_movie_review_predictor
# !python src/train.py
# Out:
# /content/imdb_movie_review_predictor
# 2026-01-29 22:49:49.589123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769726989.611733    1005 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769726989.618284    1005 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769726989.634732    1005 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r /content/file.zip /content/imdb_movie_review_predictor/experiments/distilbert_v1
# Out:
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/ (stored 0%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/ (stored 0%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/optimizer.pt (deflated 15%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/model.safetensors (deflated 8%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/trainer_state.json (deflated 65%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/scheduler.pt (deflated 62%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/config.json (deflated 45%)
#   adding: content/imdb_movie_review_predictor/experiments/distilbert_v1/checkpoint-3282/rng_state.pth (deflated 26%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")
